# %%
import ftplib
import os
import time
import pyreadr
import pandas as pd

# %%
import numpy as np
import pandas as pd
import geopandas as gpd

# %%
gpd.read_file("/pfs/work7/workspace/scratch/tu_zxobe27-master_thesis/data/misc/raw/gadm/gadm41_BRA_2.json", engine="pyogrio")
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /pfs/work7/workspace/scratch/tu_zxobe27-master_thesis/setup/miniforge3/envs/thesis/share/proj failed
#              GID_2 GID_0 COUNTRY     GID_1     NAME_1 NL_NAME_1  \
# 0        BRA.1.1_2   BRA  Brazil   BRA.1_1       Acre        NA
# 1        BRA.1.2_2   BRA  Brazil   BRA.1_1       Acre        NA
# 2        BRA.1.3_2   BRA  Brazil   BRA.1_1       Acre        NA
# 3        BRA.1.4_2   BRA  Brazil   BRA.1_1       Acre        NA
# 4        BRA.1.5_2   BRA  Brazil   BRA.1_1       Acre        NA
# ...            ...   ...     ...       ...        ...       ...
# 5567  BRA.27.135_2   BRA  Brazil  BRA.27_1  Tocantins        NA
# 5568  BRA.27.136_2   BRA  Brazil  BRA.27_1  Tocantins        NA
# 5569  BRA.27.137_2   BRA  Brazil  BRA.27_1  Tocantins        NA
# 5570  BRA.27.138_2   BRA  Brazil  BRA.27_1  Tocantins        NA
# 5571  BRA.27.139_2   BRA  Brazil  BRA.27_1  Tocantins        NA
#
# ...
